# %% [markdown]
# #**Dicionário de Dados:**

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/xAPI-Edu-Data.csv', sep=',')

# %%
df.columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
#criando o dicionario de dados

dicionario = {'variavel':['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
                          'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
                          'VisITedResources', 'AnnouncementsView', 'Discussion',
                          'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
                          'StudentAbsenceDays', 'Class'],

              'descrição': ['genero do aluno', 'nacionalidade do estudante', 'local de nascimento do estudante',
                            'etapas educacional', 'aluno de serie pertence', 'aluno da sala pertence',
                            'topico do curso','semestre que se encontra', 'nivel de parentesco','maos levantadas',
                            'recursos visitados', 'visualização do anuncio', 'grupos de discurssão',
                            'resposta dos pais para a pesquisa',
                            'satisfação da escola', 'ausencia do aluno', 'nivel do aluno na aula'],

              'type': ['nominal','nominal','nominal','nominal','nominal','nominal','nominal','nominal',
                     'nominal','discreta',
                      'discreta','discreta','discreta','nominal','nominal','nominal','nominal']}

# %%
#transformando o dicionario em um dataframe
dicionario = pd.DataFrame.from_dict(dicionario)

# %%
dicionario
# Out:
#                     variavel                          descrição      type
# 0                     gender                    genero do aluno   nominal
# 1                NationalITy         nacionalidade do estudante   nominal
# 2               PlaceofBirth   local de nascimento do estudante   nominal
# 3                    StageID                 etapas educacional   nominal
# 4                    GradeID            aluno de serie pertence   nominal
# 5                  SectionID             aluno da sala pertence   nominal
# 6                      Topic                    topico do curso   nominal
# 7                   Semester           semestre que se encontra   nominal
# 8                   Relation                nivel de parentesco   nominal
# 9                raisedhands                    maos levantadas  discreta
# 10          VisITedResources                 recursos visitados  discreta
# 11         AnnouncementsView            visualização do anuncio  discreta
# ...

# %%
#salvando o dataset
dicionario.to_csv('dicionario.csv', index=False, sep=';')
